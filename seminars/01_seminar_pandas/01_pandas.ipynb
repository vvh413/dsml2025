# %% [markdown]
# ### Семинар по работе с Pandas
# Библиотека Pandas в настоящее время является необходимой библиотекой для работы с табличными данными и обладает широким функционалом.
# К ним можно отнести:
# 1. Чтение файлов различного формата
# 2. Обрабатывать данные аналогично тому, как мы работали бы с ними в SQL
# 3. Удобная визуализация
# 4. Широкий спектр интеграций со сторонними библиотеками, такими как sklearn, polars, numpy и т.д.

# %% [markdown]
# ### Импорт данных

# %%
import pandas as pd

# %% [markdown]
# ### Основыные понятия
# Series - серия или просто колока в Pandas
#
# DataFrame - Таблица
#
# ИХ МЕТОДЫ ЧАСТО НЕ СОВПАДАЮТ!!!
#
# Нужно понимать, что в основном работаем именно с DataFrame

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.DataFrame([[1, 2], [3, 4], [5, 6]], columns=["column1", "column2"])
# Out:
#    column1  column2
# 0        1        2
# 1        3        4
# 2        5        6

# %%
### Как я люблю
pd.DataFrame(
    {
        "column1": [1, 2, 3],
        "column2": [4, 5, 6],
    }
)
# Out:
#    column1  column2
# 0        1        4
# 1        2        5
# 2        3        6

# %% [markdown]
# ###  Чтение данных
# Данные могут быть представлены в различных форматах:
# 1. CSV формат - широко распространенный формат передачи данных
# 2. XLSX формат - для удобной работы с эксель таблицами
# 3. Parquet формат - самый легкий формат передачи и хранения данных в привычном формате
#
# Самые важные аргументы при чтении файла:
#
#  - filepath_or_buffer (перый и единственный обязательный аргумент) --- имя файла
#  - sep  разделитель (; , \t ...)
#  - quotechar  символ кавычек, все что внутри считается за строку (разделители также могут входить в эту строку; ' " ...)
#  - names  список названий колонок
#  - header  номер строки файла (с 0), которую нужно считать заголовком
#  - dtype  словарь, сопоставляющий именам колонок типы данных в них

# %%
initial_data = pd.read_csv("ufc-master.csv")

# %%
### Визуализация перыых строк
initial_data.head()
# Out:
#              RedFighter           BlueFighter  RedOdds  BlueOdds  \
# 0        Brandon Moreno           Amir Albazi   -180.0     150.0
# 1      Erin Blanchfield        Rose Namajunas   -155.0     130.0
# 2          Caio Machado      Brendson Ribeiro   -192.0     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    190.0    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus   -270.0     220.0
#
#    RedExpectedValue  BlueExpectedValue        Date                   Location  \
# 0           55.5556              150.0  2024-11-02  Edmonton, Alberta, Canada
# 1           64.5161              130.0  2024-11-02  Edmonton, Alberta, Canada
# 2           52.0833              160.0  2024-11-02  Edmonton, Alberta, Canada
# 3          190.0000               40.0  2024-11-02  Edmonton, Alberta, Canada
# 4           37.0370              220.0  2024-11-02  Edmonton, Alberta, Canada
#
#   Country Winner  ...  FinishDetails FinishRound FinishRoundTime  \
# ...

# %%
### Визуализация последних строк
initial_data.tail()
# Out:
#           RedFighter     BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 6473    Duane Ludwig   Darren Elkins   -155.0     135.0           64.5161
# 6474     John Howard  Daniel Roberts   -210.0     175.0           47.6190
# 6475  Brendan Schaub   Chase Gormley   -260.0     220.0           38.4615
# 6476     Mike Pierce   Julio Paulino   -420.0     335.0           23.8095
# 6477    Eric Schafer     Jason Brilz    140.0    -160.0          140.0000
#
#       BlueExpectedValue        Date                   Location Country Winner  \
# 6473              135.0  2010-03-21  Broomfield, Colorado, USA     USA   Blue
# 6474              175.0  2010-03-21  Broomfield, Colorado, USA     USA    Red
# 6475              220.0  2010-03-21  Broomfield, Colorado, USA     USA    Red
# 6476              335.0  2010-03-21  Broomfield, Colorado, USA     USA    Red
# 6477               62.5  2010-03-21  Broomfield, Colorado, USA     USA   Blue
#
# ...

# %%
### Хотим посмотреть колонки нашей таблицы
initial_data.columns
# Out:
# Index(['RedFighter', 'BlueFighter', 'RedOdds', 'BlueOdds', 'RedExpectedValue',
#        'BlueExpectedValue', 'Date', 'Location', 'Country', 'Winner',
#        ...
#        'FinishDetails', 'FinishRound', 'FinishRoundTime', 'TotalFightTimeSecs',
#        'RedDecOdds', 'BlueDecOdds', 'RSubOdds', 'BSubOdds', 'RKOOdds',
#        'BKOOdds'],
#       dtype='object', length=118)

# %%
### Хотим посмотреть размер нашей таблицы
initial_data.shape
# Out:
# (6478, 118)

# %%
### Хотим посмотреть типы данных в колонках
initial_data.dtypes
# Out:
# RedFighter           object
# BlueFighter          object
# RedOdds             float64
# BlueOdds            float64
# RedExpectedValue    float64
#                      ...
# BlueDecOdds         float64
# RSubOdds            float64
# BSubOdds            float64
# RKOOdds             float64
# BKOOdds             float64
# Length: 118, dtype: object

# %%
### Хотим посмотреть определенные колонки и определенные строки
initial_data[:5]
# Out:
#              RedFighter           BlueFighter  RedOdds  BlueOdds  \
# 0        Brandon Moreno           Amir Albazi   -180.0     150.0
# 1      Erin Blanchfield        Rose Namajunas   -155.0     130.0
# 2          Caio Machado      Brendson Ribeiro   -192.0     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    190.0    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus   -270.0     220.0
#
#    RedExpectedValue  BlueExpectedValue        Date                   Location  \
# 0           55.5556              150.0  2024-11-02  Edmonton, Alberta, Canada
# 1           64.5161              130.0  2024-11-02  Edmonton, Alberta, Canada
# 2           52.0833              160.0  2024-11-02  Edmonton, Alberta, Canada
# 3          190.0000               40.0  2024-11-02  Edmonton, Alberta, Canada
# 4           37.0370              220.0  2024-11-02  Edmonton, Alberta, Canada
#
#   Country Winner  ...  FinishDetails FinishRound FinishRoundTime  \
# ...

# %%
initial_data.iloc[:5]
# Out:
#              RedFighter           BlueFighter  RedOdds  BlueOdds  \
# 0        Brandon Moreno           Amir Albazi   -180.0     150.0
# 1      Erin Blanchfield        Rose Namajunas   -155.0     130.0
# 2          Caio Machado      Brendson Ribeiro   -192.0     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    190.0    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus   -270.0     220.0
#
#    RedExpectedValue  BlueExpectedValue        Date                   Location  \
# 0           55.5556              150.0  2024-11-02  Edmonton, Alberta, Canada
# 1           64.5161              130.0  2024-11-02  Edmonton, Alberta, Canada
# 2           52.0833              160.0  2024-11-02  Edmonton, Alberta, Canada
# 3          190.0000               40.0  2024-11-02  Edmonton, Alberta, Canada
# 4           37.0370              220.0  2024-11-02  Edmonton, Alberta, Canada
#
#   Country Winner  ...  FinishDetails FinishRound FinishRoundTime  \
# ...

# %%
initial_data.iloc[:5, [0, 1, 3]]
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 0        Brandon Moreno           Amir Albazi     150.0
# 1      Erin Blanchfield        Rose Namajunas     130.0
# 2          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0

# %%
initial_data.loc[:5, ["RedFighter", "BlueFighter", "BlueOdds"]]
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 0        Brandon Moreno           Amir Albazi     150.0
# 1      Erin Blanchfield        Rose Namajunas     130.0
# 2          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0
# 5           Mike Malott          Trevin Giles     295.0

# %%
tmp = initial_data.loc[:5, ["RedFighter", "BlueFighter", "BlueOdds"]].copy()
tmp.index = [6, 5, 4, 3, 2, 1]

# %%
tmp.iloc[:5]
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 6        Brandon Moreno           Amir Albazi     150.0
# 5      Erin Blanchfield        Rose Namajunas     130.0
# 4          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 2  Marc-Andre Barriault      Dustin Stoltzfus     220.0

# %%
tmp.loc[:5]
# Out:
#          RedFighter     BlueFighter  BlueOdds
# 6    Brandon Moreno     Amir Albazi     150.0
# 5  Erin Blanchfield  Rose Namajunas     130.0

# %%
### Обращение к отдельным колонкам - Series
tmp.RedFighter
# Out:
# 6          Brandon Moreno
# 5        Erin Blanchfield
# 4            Caio Machado
# 3         Ariane da Silva
# 2    Marc-Andre Barriault
# 1             Mike Malott
# Name: RedFighter, dtype: object

# %%
### Обнуление индекса
tmp = tmp.reset_index(drop=True)
tmp
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 0        Brandon Moreno           Amir Albazi     150.0
# 1      Erin Blanchfield        Rose Namajunas     130.0
# 2          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0
# 5           Mike Malott          Trevin Giles     295.0

# %%
### Фильтрация данных
tmp.iloc[[True, False, True, False, False, False]]
# Out:
#        RedFighter       BlueFighter  BlueOdds
# 0  Brandon Moreno       Amir Albazi     150.0
# 2    Caio Machado  Brendson Ribeiro     160.0

# %%
tmp[tmp.BlueOdds >= 150]
# Out:
#              RedFighter       BlueFighter  BlueOdds
# 0        Brandon Moreno       Amir Albazi     150.0
# 2          Caio Machado  Brendson Ribeiro     160.0
# 4  Marc-Andre Barriault  Dustin Stoltzfus     220.0
# 5           Mike Malott      Trevin Giles     295.0

# %%
### Удаление столбцов
tmp.drop(columns=["BlueOdds", "BlueFighter"])
# Out:
#              RedFighter
# 0        Brandon Moreno
# 1      Erin Blanchfield
# 2          Caio Machado
# 3       Ariane da Silva
# 4  Marc-Andre Barriault
# 5           Mike Malott

# %%
tmp.drop("BlueOdds", axis=1)
# Out:
#              RedFighter           BlueFighter
# 0        Brandon Moreno           Amir Albazi
# 1      Erin Blanchfield        Rose Namajunas
# 2          Caio Machado      Brendson Ribeiro
# 3       Ariane da Silva  Jasmine Jasudavicius
# 4  Marc-Andre Barriault      Dustin Stoltzfus
# 5           Mike Malott          Trevin Giles

# %%
### Соединение двух таблиц
first = initial_data.loc[:4, ["RedFighter", "BlueFighter", "BlueOdds"]]
second = initial_data.loc[5:9, ["RedFighter", "BlueFighter", "BlueOdds"]]

# %%
first
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 0        Brandon Moreno           Amir Albazi     150.0
# 1      Erin Blanchfield        Rose Namajunas     130.0
# 2          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0

# %%
second
# Out:
#          RedFighter         BlueFighter  BlueOdds
# 5       Mike Malott        Trevin Giles     295.0
# 6    Aiemann Zahabi        Pedro Munhoz       NaN
# 7  Charles Jourdain        Victor Henry       NaN
# 8        Jack Shore       Youssef Zalal       NaN
# 9  Alexandr Romanov  Rodrigo Nascimento       NaN

# %%
pd.concat((first, second), axis=0)
# Out:
#              RedFighter           BlueFighter  BlueOdds
# 0        Brandon Moreno           Amir Albazi     150.0
# 1      Erin Blanchfield        Rose Namajunas     130.0
# 2          Caio Machado      Brendson Ribeiro     160.0
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0
# 5           Mike Malott          Trevin Giles     295.0
# 6        Aiemann Zahabi          Pedro Munhoz       NaN
# 7      Charles Jourdain          Victor Henry       NaN
# 8            Jack Shore         Youssef Zalal       NaN
# 9      Alexandr Romanov    Rodrigo Nascimento       NaN

# %%
pd.concat((first, second), axis=1)
# Out:
#              RedFighter           BlueFighter  BlueOdds        RedFighter  \
# 0        Brandon Moreno           Amir Albazi     150.0               NaN
# 1      Erin Blanchfield        Rose Namajunas     130.0               NaN
# 2          Caio Machado      Brendson Ribeiro     160.0               NaN
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0               NaN
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0               NaN
# 5                   NaN                   NaN       NaN       Mike Malott
# 6                   NaN                   NaN       NaN    Aiemann Zahabi
# 7                   NaN                   NaN       NaN  Charles Jourdain
# 8                   NaN                   NaN       NaN        Jack Shore
# 9                   NaN                   NaN       NaN  Alexandr Romanov
#
#           BlueFighter  BlueOdds
# 0                 NaN       NaN
# 1                 NaN       NaN
# 2                 NaN       NaN
# ...

# %%
pd.concat((first.reset_index(drop=True), second.reset_index(drop=True)), axis=1)
# Out:
#              RedFighter           BlueFighter  BlueOdds        RedFighter  \
# 0        Brandon Moreno           Amir Albazi     150.0       Mike Malott
# 1      Erin Blanchfield        Rose Namajunas     130.0    Aiemann Zahabi
# 2          Caio Machado      Brendson Ribeiro     160.0  Charles Jourdain
# 3       Ariane da Silva  Jasmine Jasudavicius    -250.0        Jack Shore
# 4  Marc-Andre Barriault      Dustin Stoltzfus     220.0  Alexandr Romanov
#
#           BlueFighter  BlueOdds
# 0        Trevin Giles     295.0
# 1        Pedro Munhoz       NaN
# 2        Victor Henry       NaN
# 3       Youssef Zalal       NaN
# 4  Rodrigo Nascimento       NaN

# %%
### Сэмплирование данных
initial_data.sample(10)
# Out:
#              RedFighter           BlueFighter  RedOdds  BlueOdds  \
# 1377   Rafael Dos Anjos        Renato Moicano   -190.0     160.0
# 1685    Islam Makhachev         Thiago Moises   -900.0     600.0
# 2087        Shane Young         Ludovit Klein    108.0    -129.0
# 1640    Jared Cannonier       Kelvin Gastelum   -145.0     125.0
# 4838       Mauricio Rua    Ovince Saint Preux   -160.0     150.0
# 4944          Mike Pyle           Jordan Mein    245.0    -265.0
# 4477     Iuri Alcantara          Leandro Issa   -250.0     210.0
# 770       Karl Williams         Chase Sherman   -420.0     330.0
# 6244  Norifumi Yamamoto    Demetrious Johnson   -115.0    -105.0
# 734    Miranda Maverick  Jasmine Jasudavicius   -235.0     194.0
#
#       RedExpectedValue  BlueExpectedValue        Date  \
# 1377           52.6316           160.0000  2022-03-05
# 1685           11.1111           600.0000  2021-07-17
# 2087          108.0000            77.5194  2020-09-26
# ...

# %%
### Удаление дубликатов
initial_data[["Date", "Location"]].drop_duplicates()
# Out:
#             Date                                    Location
# 0     2024-11-02                   Edmonton, Alberta, Canada
# 13    2024-10-26  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 26    2024-10-19                      Las Vegas, Nevada, USA
# 37    2024-10-12                      Las Vegas, Nevada, USA
# 49    2024-10-05                   Salt Lake City, Utah, USA
# ...          ...                                         ...
# 6425  2010-05-08                    Montreal, Quebec, Canada
# 6436  2010-04-10             Abu Dhabi, United Arab Emirates
# 6446  2010-03-31              Charlotte, North Carolina, USA
# 6457  2010-03-27                     Newark, New Jersey, USA
# 6467  2010-03-21                   Broomfield, Colorado, USA
#
# [565 rows x 2 columns]

# %%
initial_data[["Date", "Location"]].drop_duplicates(keep="last")
# Out:
#             Date                                    Location
# 12    2024-11-02                   Edmonton, Alberta, Canada
# 25    2024-10-26  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 36    2024-10-19                      Las Vegas, Nevada, USA
# 48    2024-10-12                      Las Vegas, Nevada, USA
# 60    2024-10-05                   Salt Lake City, Utah, USA
# ...          ...                                         ...
# 6435  2010-05-08                    Montreal, Quebec, Canada
# 6445  2010-04-10             Abu Dhabi, United Arab Emirates
# 6456  2010-03-31              Charlotte, North Carolina, USA
# 6466  2010-03-27                     Newark, New Jersey, USA
# 6477  2010-03-21                   Broomfield, Colorado, USA
#
# [565 rows x 2 columns]

# %%
### Мердж таблиц
fights = initial_data.sample(10)[["RedFighter", "BlueFighter", "Date"]]
locs = initial_data[["Date", "Location"]].drop_duplicates().reset_index(drop=True)

# %%
fights
# Out:
#               RedFighter           BlueFighter        Date
# 497      Charles Johnson        Rafael Estevam  2023-11-18
# 3986       Jose Quinonez            Joey Gomez  2016-09-17
# 3295        Ashley Yoder        Mackenzie Dern  2018-03-03
# 2601          Ciryl Gane  Raphael Pessoa Nunes  2019-08-10
# 5225       John Makdessi          Alan Patrick  2014-02-01
# 6031        John Maguire        Justin Edwards  2011-11-05
# 4418      Rose Namajunas           Angela Hill  2015-10-03
# 548   Vanessa Demopoulos         Kanako Murata  2023-10-07
# 229      Sean Strickland           Paulo Costa  2024-06-01
# 259    Terrance McKinney      Esteban Ribovics  2024-05-11

# %%
locs.iloc[:10]
# Out:
#          Date                                    Location
# 0  2024-11-02                   Edmonton, Alberta, Canada
# 1  2024-10-26  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 2  2024-10-19                      Las Vegas, Nevada, USA
# 3  2024-10-12                      Las Vegas, Nevada, USA
# 4  2024-10-05                   Salt Lake City, Utah, USA
# 5  2024-09-28                Paris, Ile-de-France, France
# 6  2024-09-14                      Las Vegas, Nevada, USA
# 7  2024-09-07                      Las Vegas, Nevada, USA
# 8  2024-08-24                      Las Vegas, Nevada, USA
# 9  2024-08-17         Perth, Western Australia, Australia

# %%
### Мердж
pd.merge(fights, locs, how="left", on="Date")
# Out:
#            RedFighter           BlueFighter        Date  \
# 0     Charles Johnson        Rafael Estevam  2023-11-18
# 1       Jose Quinonez            Joey Gomez  2016-09-17
# 2        Ashley Yoder        Mackenzie Dern  2018-03-03
# 3          Ciryl Gane  Raphael Pessoa Nunes  2019-08-10
# 4       John Makdessi          Alan Patrick  2014-02-01
# 5        John Maguire        Justin Edwards  2011-11-05
# 6      Rose Namajunas           Angela Hill  2015-10-03
# 7  Vanessa Demopoulos         Kanako Murata  2023-10-07
# 8     Sean Strickland           Paulo Costa  2024-06-01
# 9   Terrance McKinney      Esteban Ribovics  2024-05-11
#
#                               Location
# 0               Las Vegas, Nevada, USA
# 1                  Hidalgo, Texas, USA
# 2               Las Vegas, Nevada, USA
# 3                  Montevideo, Uruguay
# 4              Newark, New Jersey, USA
# 5  Birmingham, England, United Kingdom
# 6                  Houston, Texas, USA
# ...

# %%
### Мердж
pd.merge(fights, locs, how="right", on="Date").iloc[:10]
# Out:
#   RedFighter BlueFighter        Date  \
# 0        NaN         NaN  2024-11-02
# 1        NaN         NaN  2024-10-26
# 2        NaN         NaN  2024-10-19
# 3        NaN         NaN  2024-10-12
# 4        NaN         NaN  2024-10-05
# 5        NaN         NaN  2024-09-28
# 6        NaN         NaN  2024-09-14
# 7        NaN         NaN  2024-09-07
# 8        NaN         NaN  2024-08-24
# 9        NaN         NaN  2024-08-17
#
#                                      Location
# 0                   Edmonton, Alberta, Canada
# 1  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 2                      Las Vegas, Nevada, USA
# 3                      Las Vegas, Nevada, USA
# 4                   Salt Lake City, Utah, USA
# 5                Paris, Ile-de-France, France
# 6                      Las Vegas, Nevada, USA
# 7                      Las Vegas, Nevada, USA
# 8                      Las Vegas, Nevada, USA
# 9         Perth, Western Australia, Australia

# %% [markdown]
# ![Типы джоинов](images.png)

# %% [markdown]
# ### Сбор статистики
# Pandas из коробки позволяет считать основные статистики:
# 1. min
# 2. max
# 3. mean
# 4. median
# 5. quantile
# 6. std
# 7. var
# 8. count

# %%
print(
    f"""
    {initial_data.BlueOdds.min() = }
    {initial_data.BlueOdds.max() = }
    {initial_data.BlueOdds.mean() = }
    {initial_data.BlueOdds.median() = }
    {initial_data.BlueOdds.quantile(0.5) = }
    {initial_data.BlueOdds.std() = }
    {initial_data.BlueOdds.var() = }
    {initial_data.BlueOdds.count() = }
"""
)
# Out:
#     initial_data.BlueOdds.min() = np.float64(-1200.0)
#     initial_data.BlueOdds.max() = np.float64(1300.0)
#     initial_data.BlueOdds.mean() = np.float64(59.90445758108324)
#     initial_data.BlueOdds.median() = np.float64(130.0)
#     initial_data.BlueOdds.quantile(0.5) = np.float64(130.0)
#     initial_data.BlueOdds.std() = np.float64(251.81430660089583)
#     initial_data.BlueOdds.var() = np.float64(63410.445008889976)
#     initial_data.BlueOdds.count() = np.int64(6259)

# %%
initial_data[["RedFighter", "BlueFighter", "BlueOdds", "RedExpectedValue"]].describe()
# Out:
#           BlueOdds  RedExpectedValue
# count  6259.000000       6259.000000
# mean     59.904458         96.487787
# std     251.814307         85.303981
# min   -1200.000000          4.761900
# 25%    -150.000000         39.370700
# 50%     130.000000         66.666700
# 75%     215.000000        130.000000
# max    1300.000000        775.000000

# %%
### Мы можем сортировать наши данные
initial_data.BlueOdds.sort_values(ascending=False)
# Out:
# 5667    1300.0
# 4149    1200.0
# 4892    1150.0
# 4467    1100.0
# 91      1100.0
#          ...
# 1434       NaN
# 1435       NaN
# 1436       NaN
# 1437       NaN
# 1438       NaN
# Name: BlueOdds, Length: 6478, dtype: float64

# %%
### Можем группировать наши данные
initial_data.groupby("RedFighter", as_index=False).agg({"Date": "count"}).rename(
    columns={"Date": "num_of_events"}
).sort_values("num_of_events", ascending=False)
# Out:
#           RedFighter  num_of_events
# 735       Jim Miller             28
# 449   Donald Cerrone             24
# 428    Derrick Lewis             22
# 465   Dustin Poirier             22
# 1183      Neil Magny             22
# ...              ...            ...
# 11       Abu Azaitar              1
# 14     Adam Milstead              1
# 15    Adam Wieczorek              1
# 16      Adam Yandiev              1
# 1624           Yizha              1
#
# [1653 rows x 2 columns]

# %%
### Можем заполнять пропуски
initial_data.isna().any()
# Out:
# RedFighter          False
# BlueFighter         False
# RedOdds              True
# BlueOdds             True
# RedExpectedValue     True
#                     ...
# BlueDecOdds          True
# RSubOdds             True
# BSubOdds             True
# RKOOdds              True
# BKOOdds              True
# Length: 118, dtype: bool

# %%
initial_data[initial_data.RedOdds.isna()]
# Out:
#             RedFighter         BlueFighter  RedOdds  BlueOdds  \
# 6       Aiemann Zahabi        Pedro Munhoz      NaN       NaN
# 7     Charles Jourdain        Victor Henry      NaN       NaN
# 8           Jack Shore       Youssef Zalal      NaN       NaN
# 9     Alexandr Romanov  Rodrigo Nascimento      NaN       NaN
# 10        Serhiy Sidey    Garrett Armfield      NaN       NaN
# ...                ...                 ...      ...       ...
# 1435      Alexis Davis  Julija Stoliarenko      NaN       NaN
# 1436   Jailton Almeida      Danilo Marques      NaN       NaN
# 1437        Jason Witt           Phil Rowe      NaN       NaN
# 1438    Malcolm Gordon        Denys Bondar      NaN       NaN
# 1614          Rong Zhu     Brandon Jenkins      NaN     195.0
#
#       RedExpectedValue  BlueExpectedValue        Date  \
# 6                  NaN                NaN  2024-11-02
# 7                  NaN                NaN  2024-11-02
# 8                  NaN                NaN  2024-11-02
# ...

# %%
initial_data["RedOdds_new"] = initial_data.RedOdds.fillna(-9999)

# %%
initial_data[initial_data.RedOdds.isna()]
# Out:
#             RedFighter         BlueFighter  RedOdds  BlueOdds  \
# 6       Aiemann Zahabi        Pedro Munhoz      NaN       NaN
# 7     Charles Jourdain        Victor Henry      NaN       NaN
# 8           Jack Shore       Youssef Zalal      NaN       NaN
# 9     Alexandr Romanov  Rodrigo Nascimento      NaN       NaN
# 10        Serhiy Sidey    Garrett Armfield      NaN       NaN
# ...                ...                 ...      ...       ...
# 1435      Alexis Davis  Julija Stoliarenko      NaN       NaN
# 1436   Jailton Almeida      Danilo Marques      NaN       NaN
# 1437        Jason Witt           Phil Rowe      NaN       NaN
# 1438    Malcolm Gordon        Denys Bondar      NaN       NaN
# 1614          Rong Zhu     Brandon Jenkins      NaN     195.0
#
#       RedExpectedValue  BlueExpectedValue        Date  \
# 6                  NaN                NaN  2024-11-02
# 7                  NaN                NaN  2024-11-02
# 8                  NaN                NaN  2024-11-02
# ...

# %% [markdown]
# ### Apply, map, векторные функции

# %%
### APPLY
def find_potential_winner(data):
    if data.RedOdds < data.BlueOdds:
        return "Red is favorite"
    elif data.RedOdds > data.BlueOdds:
        return "Blue is favorite"
    else:
        return "equal chances"

# %%
initial_data["potential_winner"] = initial_data.apply(find_potential_winner, axis=1)

# %%
### Векторные
initial_data.RedOdds - initial_data.BlueOdds
# Out:
# 0      -330.0
# 1      -285.0
# 2      -352.0
# 3       440.0
# 4      -490.0
#         ...
# 6473   -290.0
# 6474   -385.0
# 6475   -480.0
# 6476   -755.0
# 6477    300.0
# Length: 6478, dtype: float64

# %%
### MAP
mapper = {"Red is favorite": "R", "Blue is favorite": "B", "equal chances": "E"}

# %%
initial_data["potential_winner"].map(mapper)
# Out:
# 0       R
# 1       R
# 2       R
# 3       B
# 4       R
#        ..
# 6473    R
# 6474    R
# 6475    R
# 6476    R
# 6477    B
# Name: potential_winner, Length: 6478, dtype: object
